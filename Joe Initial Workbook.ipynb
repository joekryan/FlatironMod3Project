# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# pd.options.display.max_rows = 1000
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4850765461c1> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 import researchpy as rp
#       5 from scipy import stats
#       6 import math
#
# ModuleNotFoundError: No module named 'researchpy'

# %%
df = pd.read_csv('Movies2018.csv', engine='python')

# %%
df.head()
# Out:
#   popularity      id  video  vote_count_x vote_average_x  \
# 0      82.25  299536  False       16683.0            8.3
# 1     38.895  284054  False       14192.0            7.4
# 2     31.957  351286  False        6878.0            6.5
# 3     30.431  260513  False        7607.0            7.5
# 4     31.991  297802  False        7849.0            6.8
#
#                             title release_date original_language_x  \
# 0          Avengers: Infinity War   2018-04-25                  en
# 1                   Black Panther   2018-02-13                  en
# 2  Jurassic World: Fallen Kingdom   2018-06-06                  en
# 3                   Incredibles 2   2018-06-14                  en
# 4                         Aquaman   2018-12-07                  en
#
#                    original_title            genre_ids  ...       budget  \
# 0          Avengers: Infinity War        [28, 12, 878]  ...  300000000.0
# ...

# %%
df.shape
# Out:
# (10017, 25)

# %%
df['popularity'].unique()
# Out:
# array(['82.25', '38.895', '31.957', '30.431', '31.991', '40.731',
#        '56.386', '27.848', '38.684', '32.45', '29.095', '28.192',
#        '33.307', '29.421', '17.725', '26.541', '24.078', '28.369',
#        '26.551', '37.342', '19.483', '22.069', '16.672', '18.437',
#        '41.08', '27.349', '23.348', '18.963', '20.207', '21.752',
#        '17.499', '18.799', '16.351', '9.813', '19.136', '14.604',
#        '28.813', '10.871', '18.459', '15.94', '16.759', '11.439', '2.399',
#        '21.604', '19.113', '3.817', '5.524', '25.365', '17.978', '20.946',
#        '19.47', '2.014', '0.65', '12.716', '16.592', '13.797', '14.042',
#        '1.4', '24.254', '11.489', '9.938', '14.393', '6.772', '20.935',
#        '20.88', '8.049', '19.874', '14.346', '12.461', '23.345', '11.119',
#        '5.318', '13.659', '15.495', '13.71', '11.714', '15.992', '9.899',
#        '13.17', '14.703', '12.899', '15.969', '9.254', '14.365', '8.336',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10017 entries, 0 to 10016
# Data columns (total 25 columns):
# popularity               10017 non-null object
# id                       10005 non-null object
# video                    10000 non-null object
# vote_count_x             10005 non-null float64
# vote_average_x           10005 non-null object
# title                    10005 non-null object
# release_date             10005 non-null object
# original_language_x      10005 non-null object
# original_title           10005 non-null object
# genre_ids                10004 non-null object
# backdrop_path            5460 non-null object
# adult                    10005 non-null object
# overview                 8782 non-null object
# poster_path              9225 non-null object
# belongs_to_collection    278 non-null object
# budget                   9991 non-null float64
# genres                   9991 non-null object
# original_language_y      9991 non-null object
# ...

# %%
df[df['original_language_y'] == 'zh'].count()
# Out:
# popularity               247
# id                       247
# video                    247
# vote_count_x             247
# vote_average_x           247
# title                    247
# release_date             247
# original_language_x      247
# original_title           247
# genre_ids                247
# backdrop_path            121
# adult                    247
# overview                 201
# poster_path              231
# belongs_to_collection     10
# budget                   247
# genres                   247
# original_language_y      247
# production_companies     247
# production_countries     247
# revenue                  247
# runtime                  197
# spoken_languages         247
# vote_average_y           247
# vote_count_y             247
# dtype: int64

# %%
df.genre_ids.apply(pd.Series)
# Out:
#                          0
# 0            [28, 12, 878]
# 1        [28, 12, 14, 878]
# 2            [28, 12, 878]
# 3      [28, 12, 16, 10751]
# 4             [28, 12, 14]
# ...                    ...
# 10012                   []
# 10013                   []
# 10014   [99, 10752, 10751]
# 10015                   []
# 10016                   []
#
# [10017 rows x 1 columns]

# %%
df['genres'].dropna(inplace=True)

# %%
df.shape
# Out:
# (10017, 25)

# %%
x = df['budget']
y = df['revenue']

plt.figure(figsize=(10,8))
plt.ticklabel_format(style='plain')
plt.scatter(x,y)


plt.show()

# %%
df[df['budget'] < 50000000].count()
# Out:
# popularity               9940
# id                       9940
# video                    9940
# vote_count_x             9940
# vote_average_x           9940
# title                    9940
# release_date             9940
# original_language_x      9940
# original_title           9940
# genre_ids                9940
# backdrop_path            5399
# adult                    9940
# overview                 8718
# poster_path              9171
# belongs_to_collection     251
# budget                   9940
# genres                   9940
# original_language_y      9940
# production_companies     9940
# production_countries     9940
# revenue                  9940
# runtime                  8632
# spoken_languages         9940
# vote_average_y           9940
# vote_count_y             9940
# dtype: int64

# %%
df['profitable'] = df['revenue'] - df['budget']

# %%
df.loc[df.profitable > 0, 'profitable'] = 1
df.loc[df.profitable <= 0, 'profitable'] = 0

# %%
df.sample(20)
# Out:
#      popularity      id  video  vote_count_x vote_average_x  \
# 9464        0.6  603330  False           0.0            0.0
# 7577       0.62  645073  False           0.0            0.0
# 1356      2.408  514729  False          14.0            8.1
# 15       17.725  360920  False        1503.0            6.5
# 7978        0.6  635746  False           0.0            0.0
# 4973      1.607  466361  False           4.0            5.8
# 109      11.205  454293  False         953.0            6.0
# 1225        0.6  625635  False           1.0            8.5
# 2537      1.505  476243  False           7.0            7.1
# 89        8.336  497814  False         365.0            5.8
# 4766      0.711  272094  False           1.0            6.0
# 5885      1.322  473348  False           1.0            5.0
# 7696        1.4  641625  False           0.0            0.0
# 1203       1.06  546290  False           3.0            8.7
# 2128      1.076  562722  False           4.0            7.5
# ...

# %%
df.budget.value_counts()
# Out:
# 0.0            9165
# 10000.0          34
# 1000000.0        24
# 10000000.0       20
# 5000.0           16
#                ...
# 178000000.0       1
# 127.0             1
# 1652722.0         1
# 282099.0          1
# 2424713.0         1
# Name: budget, Length: 367, dtype: int64

# %%
df.revenue.value_counts()
# Out:
# 0.0            9584
# 10000.0          14
# 100000.0          8
# 1000.0            5
# 10.0              4
#                ...
# 29163535.0        1
# 3186721.0         1
# 508575295.0       1
# 9602624.0         1
# 27506452.0        1
# Name: revenue, Length: 366, dtype: int64

# %%
df.sample(20)
# Out:
#      popularity      id  video  vote_count_x vote_average_x  \
# 1472      1.594  569402  False           1.0            8.0
# 7086        0.6  663170  False           0.0            0.0
# 865       2.124  477311  False           2.0           10.0
# 8916        0.6  615285  False           0.0            0.0
# 8437        0.6  628341  False           0.0            0.0
# 9834        0.6  595990  False           0.0            0.0
# 7718        0.6  641072  False           0.0            0.0
# 5688      2.793  545659  False           3.0            5.0
# 2706       0.66  567075  False           1.0            7.0
# 6184       2.88  538153  False           4.0            4.3
# 534       0.673  574120  False           1.0           10.0
# 2506      4.892  527281  False           3.0            7.2
# 1801       1.58  503267  False           2.0            8.0
# 5109      1.051  500176  False           5.0            5.6
# 4171        0.6  637787  False           1.0            6.0
# ...

# %%
df = df[(df.revenue != 0) & (df.budget != 0)]

# %%
test = df.loc[df.budget.notnull()]

# %%
test.reset_index(inplace=True)

# %%
test.drop(columns ='index', inplace=True)
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
pd.options.display.max_columns=1000
test
# Out:
#     popularity      id  video  vote_count_x vote_average_x  \
# 0        82.25  299536  False       16683.0            8.3
# 1       38.895  284054  False       14192.0            7.4
# 2       31.957  351286  False        6878.0            6.5
# 3       30.431  260513  False        7607.0            7.5
# 4       31.991  297802  False        7849.0            6.8
# ..         ...     ...    ...           ...            ...
# 254        0.6  638264  False           0.0            0.0
# 255        0.6  638235  False           0.0            0.0
# 256      0.651  536638  False           1.0            7.0
# 257      0.645  545943  False           1.0           10.0
# 258      1.014  483876  False           1.0            7.0
#
#                                title release_date original_language_x  \
# 0             Avengers: Infinity War   2018-04-25                  en
# 1                      Black Panther   2018-02-13                  en
# ...

# %%
test['profitable'].value_counts()
# Out:
# 1.0    174
# 0.0     85
# Name: profitable, dtype: int64

# %%
test['original_language_x'].value_counts()
# Out:
# en    186
# fa     14
# hi      9
# ru      5
# es      5
# ko      5
# ur      4
# de      4
# fr      3
# pl      3
# zh      3
# pt      2
# ml      2
# ja      2
# te      2
# tr      2
# it      1
# ro      1
# bn      1
# ta      1
# kn      1
# lv      1
# ne      1
# ar      1
# Name: original_language_x, dtype: int64

# %%
import calendar
import datetime
test['date'] = pd.to_datetime(test['release_date'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 27 columns):
# popularity               259 non-null object
# id                       259 non-null object
# video                    259 non-null object
# vote_count_x             259 non-null float64
# vote_average_x           259 non-null object
# title                    259 non-null object
# release_date             259 non-null object
# original_language_x      259 non-null object
# original_title           259 non-null object
# genre_ids                259 non-null object
# backdrop_path            216 non-null object
# adult                    259 non-null object
# overview                 253 non-null object
# poster_path              249 non-null object
# belongs_to_collection    46 non-null object
# budget                   259 non-null float64
# genres                   259 non-null object
# original_language_y      259 non-null object
# ...

# %%
test['month'] = test.date.dt.month
test['quarter'] = test.date.dt.quarter
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test
# Out:
#     popularity      id  video  vote_count_x vote_average_x  \
# 0        82.25  299536  False       16683.0            8.3
# 1       38.895  284054  False       14192.0            7.4
# 2       31.957  351286  False        6878.0            6.5
# 3       30.431  260513  False        7607.0            7.5
# 4       31.991  297802  False        7849.0            6.8
# ..         ...     ...    ...           ...            ...
# 254        0.6  638264  False           0.0            0.0
# 255        0.6  638235  False           0.0            0.0
# 256      0.651  536638  False           1.0            7.0
# 257      0.645  545943  False           1.0           10.0
# 258      1.014  483876  False           1.0            7.0
#
#                                title release_date original_language_x  \
# 0             Avengers: Infinity War   2018-04-25                  en
# 1                      Black Panther   2018-02-13                  en
# ...

# %%
import seaborn as sns

plt.figure(figsize=(15,8))
plt.ylim(top=400000000)
plt.ticklabel_format(style='plain')
sns.boxplot(x="month", y="revenue", data=test)

# %%
plt.figure(figsize=(15,8))
plt.ylim(top=200000000)
plt.ticklabel_format(style='plain')
# plt.show()
sns.boxplot(x="quarter", y="revenue", data=test)

# %%
df['vote_count_y'].describe()
# Out:
# count      259.000000
# mean      1241.822394
# std       2271.492647
# min          0.000000
# 25%          2.000000
# 50%        279.000000
# 75%       1445.000000
# max      16691.000000
# Name: vote_count_y, dtype: float64

# %%
test['popularity'] = pd.to_numeric(test['popularity'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x=test['popularity']
y=test['revenue']

plt.figure(figsize=(10,8))
# plt.ticklabel_format(style='plain')
plt.scatter(x,y)

# %%
x=test['vote_average_y']
y=test['revenue']

plt.figure(figsize=(10,8))
plt.ticklabel_format(style='plain')
plt.scatter(x,y)

# %%
plt.figure(figsize=(15,8))
plt.ylim(top=200000000)
plt.ticklabel_format(style='plain')
# plt.show()
sns.boxplot(x="profitable", y="revenue", data=test)

# %%
plt.figure(figsize=(15,8))
plt.ylim(top=200000000)
plt.ticklabel_format(style='plain')
# plt.show()
sns.boxplot(x="profitable", y="budget", data=test)

# %%
test.loc[test.original_language_y == 'en', 'English'] = 1
test.loc[test.original_language_y != 'en', 'English'] = 0
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
test
# Out:
#      popularity      id  video  vote_count_x vote_average_x  \
# 0        82.250  299536  False       16683.0            8.3
# 1        38.895  284054  False       14192.0            7.4
# 2        31.957  351286  False        6878.0            6.5
# 3        30.431  260513  False        7607.0            7.5
# 4        31.991  297802  False        7849.0            6.8
# ..          ...     ...    ...           ...            ...
# 254       0.600  638264  False           0.0            0.0
# 255       0.600  638235  False           0.0            0.0
# 256       0.651  536638  False           1.0            7.0
# 257       0.645  545943  False           1.0           10.0
# 258       1.014  483876  False           1.0            7.0
#
#                                title release_date original_language_x  \
# 0             Avengers: Infinity War   2018-04-25                  en
# 1                      Black Panther   2018-02-13                  en
# ...

# %%
plt.figure(figsize=(15,8))
plt.ylim(top=250000000)
plt.ticklabel_format(style='plain')
# plt.show()
sns.boxplot(x="English", y="revenue", data=test)

# %%
plt.figure(figsize=(15,8))
plt.ylim(top=120000000)
plt.ticklabel_format(style='plain')
# plt.show()
sns.boxplot(x="English", y="budget", data=test)

# %%
test.English.value_counts()
# Out:
# 1.0    186
# 0.0     73
# Name: English, dtype: int64
